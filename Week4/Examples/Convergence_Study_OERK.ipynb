# %% [markdown]
# ## Convergence Study of the new optimized ERK Scheme (Adection Equation)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
herk42 = [0.133333333333333,0.057142857142857,0.026666666666667,0.012903225806452,0.006349206349206,0.003149606299213,0.001568627450980,0.000782778864971,0.000391006842620,0.000195407914021]
eerk42 = [0.0037412958190229384,8.053777758237901e-5,3.029349286859384e-5,8.977460577763718e-6, 2.3341087831973972e-6,5.898425130268503e-7,1.4797556285861546e-7,3.704222961697923e-8,9.26565932313217e-9,2.3169342833195827e-9]
    
herk82 =  [0.133333333333333,0.057142857142857,0.026666666666667,0.012903225806452,0.006349206349206,0.003149606299213,0.001568627450980,0.000782778864971,0.000391006842620,0.000195407914021]   
eerk82 = [0.004069467878770161,0.00013470862673514716,8.82168307519970e-06,1.206282664922842e-06,4.6730182701182343e-07,1.337020043845616e-07,3.532009670847991e-08,9.054152011467309e-09,2.290808709393133e-09,5.760075194594094e-10]
    

plt.plot(herk42, eerk42,'-D', label = 'Optimal ERK(4, 2)')
plt.plot(herk82, eerk82, '--^', label = 'Optimal ERK(8, 2)')


plt.xscale('log')
plt.yscale('log')

plt.legend()
plt.show()

# %% [markdown]
# ### Note: the error values were obtained by running an already existed Python code (Jupyter file).
