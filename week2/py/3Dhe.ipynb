# %% [markdown]
# # Coding Heat Equation in 3D

# %%
# Enable interactive plot
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
import seaborn as sns
sns.set()


gamma = 1/4
x = np.linspace(0,1,101)
y = np.linspace(0,1,101)
X,Y = np.meshgrid(x,y)
u = np.zeros((101,101))
u[40,50] = 100
T = 400
fig = plt.figure()
ax = plt.axes(projection='3d')
ax._axis3don = False
c = ax.contourf3D(X,Y,u,1000, cmap='pink')

def ans(f):
    global u, c

    #Time is not defined as the animation will do the loop for T times.
    for j in range(100):
        for i in range(100):
            u[i, j] = gamma * (u[i+1][j] + u[i-1][j] + u[i][j+1] + u[i][j-1] - 4*u[i][j]) + u[i][j]
    for xx in c.collections:
        xx.remove()
    c = ax.contourf3D(X,Y,u,1000, cmap='pink')
    return c

anim = animation.FuncAnimation(fig, ans, frames=T)
anim.save("3dheat_equation_solution.gif")
plt.show()

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Locator attempting to generate 1001 ticks ([0.0, ..., 100.0]), which exceeds Locator.MAXTICKS (1000).
# MovieWriter ffmpeg unavailable; using Pillow instead.
# Locator attempting to generate 1001 ticks ([0.0, ..., 25.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1000 ticks ([0.0, ..., 0.14985]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1001 ticks ([0.0, ..., 0.1]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1000 ticks ([0.0, ..., 0.07992]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1002 ticks ([0.0, ..., 0.06006000000000001]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1002 ticks ([0.0, ..., 0.050050000000000004]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1000 ticks ([0.0, ..., 0.03996]), which exceeds Locator.MAXTICKS (1000).
# ...
